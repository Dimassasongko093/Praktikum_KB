# %% [markdown]
# # POSTTEST 2
# Dimas sasongko_2009106093
#
# ## Visualiasi data Yu-Gi-Oh! Trading Cards Dataset!

# %% [markdown]
# ## Import Pandas Package
# Import pandas sebagai pd
#
# Dari matplotlib import sebagai plt
#
# Import seaborn sebagai sns

# %%
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns

# %% [markdown]
# # Membaca Dataset
#
# df untuk membaca dataset

# %%
df = pd.read_csv("card_data.csv")
df
# Out:
#                           Name                     Type  Level         Race  \
# 0                Limit Reverse                Trap Card    NaN   Continuous
# 1               The 13th Grave           Normal Monster    3.0       Zombie
# 2              Gem-Enhancement                Trap Card    NaN       Normal
# 3            Magician's Circle                Trap Card    NaN       Normal
# 4     Castle of Dark Illusions      Flip Effect Monster    4.0        Fiend
# ...                        ...                      ...    ...          ...
# 6529                Wattcancel                Trap Card    NaN      Counter
# 6530    Paleozoic Anomalocaris              XYZ Monster    2.0         Aqua
# 6531             Dark Magician           Normal Monster    7.0  Spellcaster
# 6532  Odd-Eyes Pendulum Dragon  Pendulum Effect Monster    7.0       Dragon
# 6533           Stardust Dragon          Synchro Monster    8.0       Dragon
#
#      Attribute     ATK     DEF
# ...

# %%
df.dtypes
# Out:
# Name          object
# Type          object
# Level        float64
# Race          object
# Attribute     object
# ATK          float64
# DEF          float64
# dtype: object

# %% [markdown]
# ## Berikut 4 tipe Grafik visualiasi Data yang digunakan untuk data Yu-Gi-Oh! Trading Cards Dataset

# %% [markdown]
# ## Grafik Scatter Plot -------------------------------------------------------------------------------------------------------
# diagram grafis yang dibangun dari dua sumbu X dan Y (variabel X dan variabel
# Y). Scatter plot menunjukan hubungan antara dua variabel.
#
# Implementasi grafik Scatter Plot sebagai berikut

# %%
sns.scatterplot(data = df, x='Attribute', y = 'ATK')
plt.title("Persebaran data ukuran Attack dengan Attribute yang beda")
plt.show()

# %% [markdown]
# bisa diliat di atas adalah hasi visual data Grafik Scatter Plot dari data ATk dengan Atribute Yu-Gi-Oh! Trading Cards

# %% [markdown]
# ## Grafik Boxplot ------------------------------------------------------------------------------------------------------------
#
# grafik ini digunakan untuk melihat persebaran data dan mencari outliers.

# %%
sns.boxplot(x= df['ATK'], y=df['Attribute'])
plt.show()

# %% [markdown]
# ## Grafik Pie -------------------------------------------------------------------------------------------------------------------
#
# Grafik Pie cocok digunakan pada data
# categorical. Grafik ini biasa digunakan untuk melihat distribusi.

# %%
df['Attribute'].value_counts()
# Out:
# DARK      1117
# EARTH     1101
# LIGHT      849
# WATER      442
# WIND       401
# FIRE       355
# DIVINE      10
# Name: Attribute, dtype: int64

# %%
labels = df['Attribute'].value_counts().rename_axis('Attribute').reset_index(name='Jumlah')
labels
# Out:
#   Attribute  Jumlah
# 0      DARK    1117
# 1     EARTH    1101
# 2     LIGHT     849
# 3     WATER     442
# 4      WIND     401
# 5      FIRE     355
# 6    DIVINE      10

# %%
plt.figure(figsize=(8,8), dpi=300)
plt.title(' Yu-Gi-Oh! Trading Cards Attribute')
plt.pie(df['Attribute'].value_counts(), labels=labels['Attribute'], autopct='%.1f%%', startangle=90)
plt.show()

# %% [markdown]
# Diatas adalah hasil visual data pie chart diagram, dari hasil Attribute Divine memiliki nilai % terendah dengan 0.2% dan Attribute Dark memiliki % tertinggi dengan 26.1%.

# %% [markdown]
# ## Grafik Heatmap -----------------------------------------------------------------------------------------------------------
# Grafik ini biasa digunakan untuk menunjukkan korelasi antar variable, dengan cara menampilkan
# data dengan cara representasi warna yang berbeda-beda dan semakin tinggi angka suatu kelompok data maka warnanya akan
# semakin gelap.

# %%
fig, ax = plt.subplots(figsize=(10,6))
sns.heatmap(df.corr(), cmap='Oranges')
ax.set_title('Korelasi antar atribut DEF, ATK dan Level pada data Yu-Gi-Oh! Trading Cards Dataset')
plt.show()

# %% [markdown]
# ##### kolerelasi Level dengan Level memiliki nilai yang tinggi
# ##### kolerelasi Level dengan ATK memiliki nilai yang sedang
# ##### kolerelasi Level dengan DEF memiliki nilai yang rendah

# %% [markdown]
# ##### kolerelasi ATK dengan Level memiliki nilai yang sedang
# ##### kolerelasi ATK dengan ATK memiliki nilai yang  tinggi
# ##### kolerelasi ATK dengan DEF memiliki nilai yang sangant rendah

# %% [markdown]
# ##### kolerelasi DEF dengan Level memiliki nilai yang rendah
# ##### kolerelasi DEF dengan ATK memiliki nilai yang sangant rendah
# ##### kolerelasi DEF dengan DEF memiliki nilai yang tinggi
